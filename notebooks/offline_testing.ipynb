# %%
import joblib

# %%
loaded_model = joblib.load("../models/engineered/LogisticRegression.joblib")

# %%
loaded_model
# Out:
# OneVsOneClassifier(estimator=LogisticRegression(max_iter=1000, random_state=42))

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score

# --- Offline unseen hotel (all features including ) ---
new_hotel = pd.DataFrame({
    'title': ["AL MARYAM Mehmonxonasi"],
    'price': [30],
    'adults': [4],
    'city': ["tashkent"],
    'distance_to_center': [0.1],
    'description': ["4 kishilik"],
    'bf_has_included': [False]
})

# --- Predict for offline hotel ---
pred_hotel_category = loaded_model.predict(new_hotel)[0]


print("\n--- Offline (Unseen) Hotel Test ---", pred_hotel_category)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 17
#       6 new_hotel = pd.DataFrame({
#       7     'title': ["AL MARYAM Mehmonxonasi"],
#       8     'price': [30],
#    (...)
#      13     'bf_has_included': [False]
#      14 })
#      16 # --- Predict for offline hotel ---
# ---> 17 pred_hotel_category = loaded_model.predict(new_hotel)[0]
#      20 print("\n--- Offline (Unseen) Hotel Test ---", pred_hotel_category)
#
# File ~/Documents/hotel_price_category/myenv/lib/python3.9/site-packages/sklearn/multiclass.py:945, in OneVsOneClassifier.predict(self, X)
#     928 def predict(self, X):
#     929     """Estimate the best class label for each sample in X.
#     930
#     931     This is implemented as ``argmax(decision_function(X), axis=1)`` which
#    (...)
#     943         Predicted multi-class targets.
#     944     """
# ...

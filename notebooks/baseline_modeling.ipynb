# %%
import sys
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier

sys.path.append("..")

from src.data_loader import DataLoader
from src.logger import Logger
from src.pipeline import HotelPipeline

# %%
loader=DataLoader("../data/merged/hotels.csv", "baseline_modeling")

# %%
df=loader.load()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   title               1258 non-null   object
#  1   price               1258 non-null   float64
#  2   adults              1258 non-null   int64
#  3   city                1258 non-null   object
#  4   distance_to_center  1258 non-null   float64
#  5   description         1258 non-null   object
#  6   bf_has_included     1258 non-null   bool
#  7   price_category      1258 non-null   object
# dtypes: bool(1), float64(2), int64(1), object(4)
# memory usage: 70.2+ KB

# %%
df.head()
# Out:
#                     title  adults       city  distance_to_center  \
# 0  Bex Sueno Mehmonxonasi       1  samarkand                 3.7
# 1  AL MARYAM Mehmonxonasi       1  samarkand                 1.2
# 2  SAM GREEN HOUSE hostel       1  samarkand                 7.7
# 3              Safi Plaza       1  samarkand                 1.2
# 4        Azam Plaza Hotel       1  samarkand                 5.0
#
#                                          description  bf_has_included  \
# 0                          Bir kishilik Delyuks xona             True
# 1   Bitta katta to'shakli ikki kishilik Delyuks xona             True
# 2              7 kishilik erkaklar uchun umumiy xona            False
# 3   Bitta katta to'shakli ikki kishilik Delyuks xona             True
# 4  Ikkita alohida to'shakli ikki kishilik standar...             True
#
#   price_category
# 0         Budget
# 1         Budget
# 2         Budget
# 3         Budget
# 4         Budget

# %%
df.drop(columns=["price"], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   title               1258 non-null   object
#  1   adults              1258 non-null   int64
#  2   city                1258 non-null   object
#  3   distance_to_center  1258 non-null   float64
#  4   description         1258 non-null   object
#  5   bf_has_included     1258 non-null   bool
#  6   price_category      1258 non-null   object
# dtypes: bool(1), float64(1), int64(1), object(4)
# memory usage: 60.3+ KB

# %% [markdown]
# # Logistic Regression

# %%
pipeline = HotelPipeline(
  df=df, 
  target="price_category", 
  log_file="baseline_modeling",
  model=LogisticRegression()
)

sa = pipeline.fit()

y_pred = pipeline.predict()

print("Accuracy Score:", pipeline.score())
# Out:
# Accuracy Score: 0.5516693163751988
# /Users/asadbek/Documents/hotel_price_category/myenv/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# # Decisiontree Classifier

# %%
pipeline = HotelPipeline(
  df=df, 
  target="price_category", 
  log_file="baseline_modeling",
  model=DecisionTreeClassifier()
)

pipeline.fit()

y_pred = pipeline.predict()

print("Accuracy Score:", pipeline.score())
# Out:
# Accuracy Score: 1.0

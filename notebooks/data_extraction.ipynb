# %%
import sys

sys.path.append("..")

from src.data_extraction import Hotel_Scraper
# Out:
# /Users/asadbek/Documents/hotel_price_category/myenv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
hotel_scraper = Hotel_Scraper()

# %%
hotel_scraper.scrape_all()
# Out:
# Request failed: HTTPSConnectionPool(host='mybooking.uz', port=443): Max retries exceeded with url: /uz/hotels/tashkent?hotel_id=&checkin=10.07.2026&checkout=11.07.2026&adults=6 (Caused by NewConnectionError("HTTPSConnection(host='mybooking.uz', port=443): Failed to establish a new connection: [Errno 65] No route to host"))
# Request failed: HTTPSConnectionPool(host='mybooking.uz', port=443): Max retries exceeded with url: /uz/hotels/bukhara?hotel_id=&checkin=10.07.2026&checkout=11.07.2026&adults=3 (Caused by NewConnectionError("HTTPSConnection(host='mybooking.uz', port=443): Failed to establish a new connection: [Errno 65] No route to host"))
# Request failed: HTTPSConnectionPool(host='mybooking.uz', port=443): Max retries exceeded with url: /uz/hotels/bukhara?hotel_id=&checkin=10.07.2026&checkout=11.07.2026&adults=5 (Caused by NewConnectionError("HTTPSConnection(host='mybooking.uz', port=443): Failed to establish a new connection: [Errno 65] No route to host"))
# ...

# %%
import pandas as pd

df = pd.read_csv("../data/cities/tashkent.csv")

# %%
df.head()
# Out:
#                          title  price  adults      city  distance_to_center  \
# 0         Haziniy Mehmonxonasi  37.46       1  tashkent                 4.1
# 1      North Star Mehmonxonasi  45.78       1  tashkent                 2.3
# 2                Samanid Hotel  37.46       1  tashkent                 5.7
# 3            City Mehmonxonasi  33.71       1  tashkent                 3.5
# 4  South Tashkent Mexmonxonasi  29.97       1  tashkent                 6.8
#
#                                          description  bf_has_included
# 0    "King-size" o'lchamdagi to'shakli standart xona             True
# 1           "Komfort" toifasidagi ikki kishilik xona             True
# 2                           Katta ikki kishilik xona             True
# 3  Ikkita alohida to'shakli ikki kishilik standar...             True
# 4                          Bir kishilik Delyuks xona             True

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 282 entries, 0 to 281
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   title               282 non-null    object
#  1   price               282 non-null    float64
#  2   adults              282 non-null    int64
#  3   city                282 non-null    object
#  4   distance_to_center  282 non-null    float64
#  5   description         282 non-null    object
#  6   bf_has_included     282 non-null    bool
# dtypes: bool(1), float64(2), int64(1), object(3)
# memory usage: 13.6+ KB

# %%
df.tail(40)
# Out:
#                             title   price  adults      city  \
# 242     NINETY Butik Mehmonxonasi  152.33       7  tashkent
# 243       Arda Plaza Mehmonxonasi  120.70       7  tashkent
# 244           Barhat Mehmonxonasi  166.48       7  tashkent
# 245           SOLIEF Mehmonxonasi  141.51       7  tashkent
# 246       Art Deluxe Mehmonxonasi  189.79       7  tashkent
# 247        Xon Palace by Reikartz  211.43       7  tashkent
# 248       Beshchinor Mehmonxonasi  153.16       7  tashkent
# 249         Lakeside Mehmonxonasi  233.07       7  tashkent
# 250         Old City Mehmonxonasi   83.24       7  tashkent
# 251             Expo Mehmonxonasi  191.45       7  tashkent
# 252           Sumaya Mehmonxonasi  121.45       7  tashkent
# 253           Muhsin Mehmonxonasi  179.96       7  tashkent
# 254              AKS Mehmonxonasi  162.32       7  tashkent
# 255               The Art Hosteli  454.49       7  tashkent
# 256       Home Butik Mehmonxonasi  324.63       7  tashkent
# ...

# %%
df.shape
# Out:
# (282, 7)

# %%
hotel_scraper.merge_csv_files()
# Out:
#                          title   price  adults       city  distance_to_center  \
# 0       Bex Sueno Mehmonxonasi   26.55       1  samarkand                 3.7
# 1       AL MARYAM Mehmonxonasi   31.84       1  samarkand                 1.2
# 2       SAM GREEN HOUSE hostel    8.32       1  samarkand                 7.7
# 3                   Safi Plaza   41.62       1  samarkand                 1.2
# 4             Azam Plaza Hotel   41.62       1  samarkand                 5.0
# ...                        ...     ...     ...        ...                 ...
# 1253             Al-Amin Hotel  174.80       6     termez                 2.5
# 1254    Reikartz Termez Palace  237.23       6     termez                 1.5
# 1255  Gold Palace Mehmonxonasi  187.29       6     termez                 2.1
# 1256           Marshal Hosteli   54.11       6     termez                 4.4
# 1257     Fayz Tillo Mehmon uyi   99.89       6     termez                 1.6
#
# ...

# %%
hotels_data=pd.read_csv("../data/merged/hotels.csv")

# %%
hotels_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   title               1258 non-null   object
#  1   price               1258 non-null   float64
#  2   adults              1258 non-null   int64
#  3   city                1258 non-null   object
#  4   distance_to_center  1258 non-null   float64
#  5   description         1258 non-null   object
#  6   bf_has_included     1258 non-null   bool
# dtypes: bool(1), float64(2), int64(1), object(3)
# memory usage: 60.3+ KB

# %%
hotels_data["title"].value_counts()
# Out:
# title
# Shedevr Plaza Mehmonxonasi       10
# Uzbekistan Mehmonxonasi           9
# NOVA HOTEL                        7
# DUNYO Jizzax                      7
# One Global Oilaviy mehmon uyi     7
#                                  ..
# Osiyo Palace Mehmonxonasi         1
# IRIS Mehmonxonasi                 1
# TTT Hosteli                       1
# Nur Hosteli                       1
# VIRA Mehmonxonasi                 1
# Name: count, Length: 297, dtype: int64

# %%
hotels_data["price"].describe()
# Out:
# count    1258.000000
# mean      111.681955
# std        86.658316
# min         2.000000
# 25%        49.940000
# 50%        83.240000
# 75%       149.830000
# max       790.550000
# Name: price, dtype: float64

# %%
hotels_data["price"].mean()
# Out:
# np.float64(111.68195548489666)

# %%
hotels_data["price"].mode()
# Out:
# 0    49.94
# Name: price, dtype: float64

# %%
hotels_data["price"].min()
# Out:
# np.float64(2.0)

# %%
hotels_data["price"].max()
# Out:
# np.float64(790.55)

# %%
hotels_data["price_category"] = pd.qcut(
    hotels_data["price"],
    q=4,
    labels=[
        "Budget",
        "Standard",
        "Premium",
        "Luxury"
    ]
)

# %%
hotels_data.head()
# Out:
#                     title  price  adults       city  distance_to_center  \
# 0  Bex Sueno Mehmonxonasi  26.55       1  samarkand                 3.7
# 1  AL MARYAM Mehmonxonasi  31.84       1  samarkand                 1.2
# 2  SAM GREEN HOUSE hostel   8.32       1  samarkand                 7.7
# 3              Safi Plaza  41.62       1  samarkand                 1.2
# 4        Azam Plaza Hotel  41.62       1  samarkand                 5.0
#
#                                          description  bf_has_included  \
# 0                          Bir kishilik Delyuks xona             True
# 1   Bitta katta to'shakli ikki kishilik Delyuks xona             True
# 2              7 kishilik erkaklar uchun umumiy xona            False
# 3   Bitta katta to'shakli ikki kishilik Delyuks xona             True
# 4  Ikkita alohida to'shakli ikki kishilik standar...             True
#
#   price_category
# 0         Budget
# 1         Budget
# 2         Budget
# 3         Budget
# 4         Budget

# %%
df=hotel_scraper.merge_csv_files()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   title               1258 non-null   object
#  1   price               1258 non-null   float64
#  2   adults              1258 non-null   int64
#  3   city                1258 non-null   object
#  4   distance_to_center  1258 non-null   float64
#  5   description         1258 non-null   object
#  6   bf_has_included     1258 non-null   bool
#  7   price_category      1258 non-null   object
# dtypes: bool(1), float64(2), int64(1), object(4)
# memory usage: 70.2+ KB

# %%
df["price_category"].value_counts()
# Out:
# price_category
# Standard    337
# Luxury      327
# Premium     314
# Budget      280
# Name: count, dtype: int64
